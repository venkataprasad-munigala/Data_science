# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import plotly.express as px

# %%
az_df = pd.read_csv('./amazon_camphor.csv')
fk_df = pd.read_csv('./flipkart_camphor.csv')

# %%
az_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    306 non-null    int64
#  1   Name          306 non-null    object
#  2   Description   306 non-null    object
#  3   Price         304 non-null    object
#  4   Rating        245 non-null    object
#  5   Rating_Count  235 non-null    object
#  6   URL           306 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 16.9+ KB

# %%
az_df.sample(5)
# Out:
#      Unnamed: 0        Name  \
# 31           31    SHIVANSH
# 192         192    Aatiutik
# 117         117       GECKO
# 26           26       PANCA
# 255         255  ELISBURRY®
#
#                                            Description   Price  \
# 31   SHIVANSH TECHNOLOGY Multipurpose Special Grade...    ₹425
# 192  Aatiutik Ceramic Kapur Dani | Electrical Camph...    ₹437
# 117  GECKO K17CAS 17 Keys Kalimba Camphor Wood with...  ₹3,230
# 26   PANCA Kapoor Dani Camphor Diffuser for Home Ba...    ₹260
# 255  ELISBURRY® Rose Fragrance Camphor Cone 100% Pu...   ₹314.
#
#                  Rating Rating_Count  \
# 31                  4.0        7,035
# 192                 4.1            5
# 117  4.3 out of 5 stars         (12)
# 26                  3.8          492
# 255                 NaN          NaN
#
#                                                    URL
# 31   https://www.amazon.in/SHIVANSH-TECHNOLOGY%C2%A...
# 192  https://www.amazon.in/Aatiutik-Ceramic-Electri...
# ...

# %%
fk_df.sample(5)
# Out:
#      Unnamed: 0       Name                                        Description  \
# 166         166          H                    H HADDU Brass  (1 Pieces, Gold)
# 327         327  Naturalis  Naturalis Camphor Essential Oil for Skin & Hai...
# 51           51  Stylewell  Stylewell Combo of 5 Face Puja Camphor Burner ...
# 99           99   bhimseni                 bhimseni kapoor nidhi kapoor 100gm
# 231         231    Utkarsh  Utkarsh Combo Of 5 Face Puja Camphor Burner La...
#
#     Price Rating              Rating_Count  \
# 166  ₹567
# 327  ₹258
# 51   ₹385
# 99   ₹199    4.1    48 Ratings & 0 Reviews
# 231  ₹337      4  310 Ratings & 19 Reviews
#
#                                                    URL
# 166  https://www.flipkart.com/h-haddu-brass/p/itm0b...
# 327  https://www.flipkart.com/naturalis-camphor-ess...
# 51   https://www.flipkart.com/stylewell-combo-5-fac...
# 99   https://www.flipkart.com/bhimseni-kapoor-nidhi...
# ...

# %%
az_df.duplicated().sum()
# Out:
# 0

# %%
fk_df.duplicated().sum()
# Out:
# 0

# %%
az_df['ecomm'] = 'amazon'
az_df.sample(5)
# Out:
#      Unnamed: 0           Name  \
# 294         294        DRAMIQ®
# 238         238        360feel
# 299         299       Mangalam
# 170         170  Gurushraddha®
# 25           25            Maa
#
#                                            Description Price Rating  \
# 294  DRAMIQ® Beautiful Kapoor Dani/Shock Proof Desi...  ₹469    2.9
# 238  360feel Bhimseni Camphor 250gm Premium Kapoor ...  ₹679    4.3
# 299                 Mangalam Camphor Butter Paper 400g  ₹800    NaN
# 170  Gurushraddha® Bhimseni Camphor Brass Desi Pure...  ₹499    5.0
# 25   Maa Kapoor Dani Electrical Black Coated Campho...  ₹239    4.3
#
#     Rating_Count                                                URL   ecomm
# 294          NaN  https://www.amazon.in/Beautiful-Diffuser-Essen...  amazon
# 238           16  https://www.amazon.in/isoborneol-karpooram-Med...  amazon
# 299          NaN  https://www.amazon.in/Mangalam-Camphor-Butter-...  amazon
# ...

# %%
az_df['currency'] = az_df.Price.str[0]

# %%
az_df.sample(5)
# Out:
#      Unnamed: 0      Name                                        Description  \
# 253         253   DRAMIQ®  DRAMIQ® Beautiful Kapoor Dani/Shock Proof Desi...
# 225         225  Electric  Electric Kapoor dani Incense Burner Aroma Oil ...
# 138         138     YOUNG  YOUNG CHEMIST Natural Undiluted Therapeutic Gr...
# 230         230      Shri  Shri Ganesh Premium Camphor Bhimseni Camphor, ...
# 11           11  Mangalam  Mangalam CamPure Camphor Power Mosquito Liquid...
#
#     Price              Rating Rating_Count  \
# 253  ₹469                 2.9            6
# 225  ₹225                 NaN          NaN
# 138  ₹399  3.9 out of 5 stars         (56)
# 230  ₹230                 4.2          232
# 11   ₹288                 3.7        5,894
#
#                                                    URL   ecomm currency
# 253  https://www.amazon.in/Beautiful-Diffuser-Essen...  amazon        ₹
# 225  https://www.amazon.in/Electric-Incense-Kapoord...  amazon        ₹
# ...

# %%
az_df['Price'] = az_df.Price.str[1:]

# %%
az_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    306 non-null    int64
#  1   Name          306 non-null    object
#  2   Description   306 non-null    object
#  3   Price         304 non-null    object
#  4   Rating        245 non-null    object
#  5   Rating_Count  235 non-null    object
#  6   URL           306 non-null    object
#  7   ecomm         306 non-null    object
#  8   currency      304 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 21.6+ KB

# %%
az_df.Price = az_df.Price.str.replace('.', '')
az_df.Price = az_df.Price.str.replace(',', '')

# %%
az_df.dropna(subset=['Price'], inplace=True)

# %%
az_df.Price = pd.to_numeric(az_df.Price)

# %%
az_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 304 entries, 0 to 305
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    304 non-null    int64
#  1   Name          304 non-null    object
#  2   Description   304 non-null    object
#  3   Price         304 non-null    int64
#  4   Rating        244 non-null    object
#  5   Rating_Count  234 non-null    object
#  6   URL           304 non-null    object
#  7   ecomm         304 non-null    object
#  8   currency      304 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 23.8+ KB

# %%
fk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    329 non-null    int64
#  1   Name          329 non-null    object
#  2   Description   329 non-null    object
#  3   Price         329 non-null    object
#  4   Rating        329 non-null    object
#  5   Rating_Count  329 non-null    object
#  6   URL           329 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 18.1+ KB

# %%
fk_df.sample(5)
# Out:
#      Unnamed: 0         Name  \
# 217         217  De-Ultimate
# 297         297          Zed
# 76           76      Utkarsh
# 178         178         Hari
# 184         184         SHRI
#
#                                            Description Price Rating  \
# 217  De-Ultimate Combo of 5 Face Puja Camphor Burne...  ₹451    3.7
# 297  Zed Black Pure & Natural Bhimseni Camphor Kapo...  ₹280    4.5
# 76   Utkarsh Combo Of Kapoor/camphor Diffuser Brass...  ₹555
# 178               Hari Darshan Bhimseni Camphor (150g)  ₹292    4.4
# 184  SHRI ANAND Combo Of 5 Face Puja Camphor Burner...  ₹343    4.3
#
#                  Rating_Count  \
# 217  114 Ratings & 12 Reviews
# 297    11 Ratings & 2 Reviews
# 76
# 178  281 Ratings & 12 Reviews
# 184    71 Ratings & 6 Reviews
#
#                                                    URL
# 217  https://www.flipkart.com/de-ultimate-combo-5-f...
# 297  https://www.flipkart.com/zed-black-pure-natura...
# ...

# %%
fk_df['Currency'] = fk_df.Price.str[0]

# %%
fk_df.Price = fk_df.Price.str[1:]

# %%
fk_df.Price = fk_df.Price.str.replace('.', '')
fk_df.Price = fk_df.Price.str.replace(',', '')

# %%
fk_df.Price = pd.to_numeric(fk_df.Price)

# %%
fk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    329 non-null    int64
#  1   Name          329 non-null    object
#  2   Description   329 non-null    object
#  3   Price         329 non-null    int64
#  4   Rating        329 non-null    object
#  5   Rating_Count  329 non-null    object
#  6   URL           329 non-null    object
#  7   Currency      329 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 20.7+ KB

# %%
df_merge = pd.concat([az_df, fk_df])

# %%
df_merge.sample(5)
# Out:
#      Unnamed: 0         Name  \
# 172         172      Ayodhya
# 116         116     Mangalam
# 2             2     MANGALAM
# 79           79    Saraswati
# 217         217  De-Ultimate
#
#                                            Description  Price  \
# 172  Ayodhya Bhakti Vat Savitri Puja Samagri kit !!...    349
# 116                         Mangalam Wooden Kapur Dani    230
# 2         MANGALAM Camphor Tablet 250g Jar - Pack of 1    370
# 79                     Saraswati Camphor Slab (500 gm)    699
# 217  De-Ultimate Combo of 5 Face Puja Camphor Burne...    451
#
#                  Rating              Rating_Count  \
# 172                 4.3    15 Ratings & 1 Reviews
# 116  1.0 out of 5 stars                       (1)
# 2                   4.5  743 Ratings & 43 Reviews
# 79                  4.2                      (12)
# 217                 3.7  114 Ratings & 12 Reviews
#
#                                                    URL   ecomm currency  \
# ...

# %%
df_merge.ecomm.fillna('flipkart', inplace=True)

# %%
df_merge.currency.fillna('₹', inplace=True)

# %%
df_merge.drop(columns=['Currency'], inplace=True)

# %%
df_merge.sample(5)
# Out:
#      Unnamed: 0         Name  \
# 278         278  De-Ultimate
# 305         305    Essential
# 241         241      Utkarsh
# 28           28      360feel
# 242         242      RAMNATH
#
#                                            Description  Price Rating  \
# 278  De-Ultimate Combo of 5 Face Puja Camphor Burne...    451    3.7
# 305  Essential Product Electric Stainless Steel Inc...    125    3.5
# 241  Utkarsh Combo Of Kapoor/camphor Diffuser Brass...    646
# 28   360feel Bhimseni Camphor Kapur karpur Kapoor K...    499      4
# 242  RAMNATH Camphor Tablet Jar (Camphor Tablet Jar...    110    NaN
#
#                  Rating_Count  \
# 278  114 Ratings & 12 Reviews
# 305                       NaN
# 241
# 28      6 Ratings & 1 Reviews
# 242                       NaN
#
#                                                    URL     ecomm currency
# 278  https://www.flipkart.com/de-ultimate-combo-5-f...  flipkart        ₹
# ...

# %%
df_merge.Rating.unique()
# Out:
# array(['4.3', '4.4', '4.2', '4.1', '4.8', '3.7', '5.0', '3.9', '3.8',
#        '3.5', '4.0', '2.0', '4.7', '3.4', '4.6', nan, '3.3', '3.2', '3.0',
#        '3.6', '4.5', '1.0', '3.1', '2.4', '4.9', '2.5', '2.8', '2.9',
#        '2.7', ' ', '4'], dtype=object)

# %%
df_merge.Rating = df_merge.Rating.str.replace(' out of 5 stars', '')

# %%
df_merge.sample(5)
# Out:
#     Unnamed: 0      Name                                        Description  \
# 49          49       ILT  ILT Retail - (50gms/135 Tablets Approx) Pure C...
# 64          64  Mangalam  Mangalam CamPure Camphor Cone (Sandalwood) Pac...
# 97          97  Mangalam                  Mangalam Camphor Block 250g Pouch
# 51          51    Heilen  Heilen Biopharm Camphor (Cinnamomum camphora) ...
# 12          12  Mangalam                   Mangalam Camphor Thal 250g Pouch
#
#     Price Rating Rating_Count  \
# 49     79    3.4          (6)
# 64    763    4.3        (648)
# 97    300    5.0          (3)
# 51    149    3.3          (6)
# 12    336    5.0            3
#
#                                                   URL   ecomm currency
# 49  https://www.amazon.in/ILT-Retail-Kapooram-Karp...  amazon        ₹
# 64  https://www.amazon.in/Mangalam-CamPure-Sandalw...  amazon        ₹
# 97  https://www.amazon.in/Mangalam-Camphor-Block-2...  amazon        ₹
# ...

# %%
df_merge.Rating_Count = df_merge.Rating_Count.str.replace(',', '')

# %%
df_merge[['Rating_Count', 'Review_count']] = df_merge.Rating_Count.str.split('Ratings', expand=True)

# %%
df_merge.drop(columns=['Review_count'], inplace=True)
